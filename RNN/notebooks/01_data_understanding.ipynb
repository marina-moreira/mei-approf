# %% [markdown]
# <h1 style="background-color:#C2B4B9;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 5px 5px;"><strong><centre>Motion Activity Classification Using Recurrent Neural Networks </centre></strong></h1>

# %% [markdown]
# <h2 style="background-color:#C2B4B9;color:white;text-align: center;padding-top: 5px;padding-bottom: 5px;border-radius: 5px 5px;"><strong><centre>Methodology: Exploratory Analysis of Motion Activity Dataset</centre></strong></h2>
#
#
# #### 01. Data Understanding <a class="anchor" id="data"></a>
#
# ##### Exploratory data analysis will help us understand the structure, quality, and characteristics of the dataset. We will inspect the properties of the time series data, check for missing or corrupted values, and visualize samples to gain insights that will inform our data preprocessing and modeling steps.
#
# ---

# %% [markdown]
# # **Compreensão dos Dados**

# %% [markdown]
# ## **Carregamento das Bibliotecas Base**

# %%
import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

sns.set_style("whitegrid")
sns.color_palette("bone_r", as_cmap=True)

# %% [markdown]
# ## **Carregamento e Análise do Dataset**

# %% [markdown]
# + Definição dos caminhos para o ficheiro .csv com os dados dos 24 participantes ('subject_data_file') e para a pasta com os dados das várias atividades ('data_dir')

# %%
# Obter o diretório atual de trabalho
#base_dir = os.getcwd()
base_dir = r'C:\\Users\\maria\\OneDrive - Instituto Superior de Engenharia do Porto\\Desktop\\Semestre\\APROF\\mei-approf\\RNN\\datasets'

# Construir caminhos relativos aos arquivos
subject_data_file = os.path.join(base_dir, 'data_subjects_info.csv')
data_dir = os.path.join(base_dir, 'A_DeviceMotion_data')

# %% [markdown]
# Este projeto tem por objetivo desenvolver um modelo de deep learning utilizando Redes Neuronais Recorrentes (RNNs) para classificar atividades de movimento com base em dados sensoriais capturados por sensores de movimento. O conjunto de dados utilizado contém informações sobre seis atividades diferentes:
#
#    + dws: descer escadas;
#
#    + ups: subir escadas;
#
#    + sit: sentar;
#
#    + std: ficar em pé;
#
#    + wlk: caminhar;
#
#    + jog: correr.
#
# Para simplificar a complexidade e focar na eficácia do modelo, restringiu-se a previsão a apenas três destas seis atividades. Portanto, o objetivo será prever, com base nos dados de movimento dos utilizadores, apenas três das seguintes atividades:
#
#    + ups;
#
#    + jog;
#
#    + dws.
#
#
# A escolha destas três atividades foi feita de forma aleatória.

# %% [markdown]
# + Definição da função para obter todos os caminhos das pastas de cada atividade, que se encontram dentro da pasta 'A_DeviceMotion_data'

# %% [markdown]
# `get_all_dataset_paths`: Percorre recursivamente todos os subdiretórios do diretório especificado em 'input_dir' e recolhe os caminhos de todos os ficheiros .csv nas pastas que começam com 'ups', 'jog' ou 'dws'

# %%
def get_all_dataset_paths(input_dir) -> []:
    input_files = []
    for dirs, subdirs, files in os.walk(input_dir):
        for file in files:
            if file.endswith('.csv'):
                dir_name = os.path.basename(dirs)
                if dir_name.startswith(('ups', 'jog', 'dws')):
                    input_files.append(os.path.join(dirs, file))
    return input_files

# %% [markdown]
# + Definição da função para carregar os dados e combinar com Metadados

# %% [markdown]
# `load_whole_dataframe_from_paths`: Carrega cada arquivo CSV listado em 'paths', adiciona colunas de metadados (subject_id, session_id, category, age, gender, height, weight) e concatena todos os dados num único DataFrame.

# %%
def load_whole_dataframe_from_paths(paths, meta) -> pd.DataFrame:
    
    df = pd.DataFrame()

    for path in paths:
        c_dir, c_file = path.split('\\')[-2], p.split('\\')[-1]
        c_cat, c_ses = c_dir.split('_')[-2], c_dir.split('_')[-1]
        c_sub = c_file.split('_')[-1].split('.')[-2]
        
        mtdf = pd.read_csv(path, encoding = "utf-8")
        mtdf = mtdf.assign(subject_id = int(c_sub))
        mtdf = mtdf.assign(session_id = int(c_ses))
        mtdf = mtdf.assign(category = str(c_cat))
        mtdf = mtdf.assign(age = int(meta.age[int(c_sub) - 1]))
        mtdf = mtdf.assign(gender = int(meta.gender[int(c_sub) - 1]))
        mtdf = mtdf.assign(height = int(meta.height[int(c_sub) - 1]))
        mtdf = mtdf.assign(weight = int(meta.weight[int(c_sub) - 1]))

        df = pd.concat([df, mtdf])
    
    df.reset_index(drop=True, inplace=True)
    return df

# %% [markdown]
# + Construção do Dataframe inicial

# %% [markdown]
# `subject_data_frame`: Carrega os metadados dos participantes a partir do ficheiro .csv e transforma no Dataframe.
#
# `all_dataset_paths`: Obtém todos os caminhos dos ficheiros especificos do diretório de dados.
#
# `data_frame`: Carrega e combina todos os dados dos ficheiros .csv com os metadados.

# %%
subject_data_frame = pd.DataFrame(pd.read_csv(subject_data_file, encoding = "utf-8"))

all_dataset_paths = get_all_dataset_paths(data_dir)

df_motionSense = load_whole_dataframe_from_paths(all_dataset_paths, subject_data_frame)

# %% [markdown]
# + Guardar o *dataset* resultante no diretório específico utilizando o método `to_cvs()`

# %%
output_file_path = os.path.join(base_dir, 'concatDataset.csv')

df_motionSense.to_csv(output_file_path, index=False)

# %% [markdown]
# + Utilização do método `head()` para visualizar os 10 primeiros valores do Dataframe 'df_motionSense'

# %%
df_motionSense.head(10)
# Out:
#    Unnamed: 0  attitude.roll  attitude.pitch  attitude.yaw  gravity.x  \
# 0           0       1.528132       -0.733896      0.696372   0.741895
# 1           1       1.527992       -0.716987      0.677762   0.753099
# 2           2       1.527765       -0.706999      0.670951   0.759611
# 3           3       1.516768       -0.704678      0.675735   0.760709
# 4           4       1.493941       -0.703918      0.672994   0.760062
# 5           5       1.476302       -0.700807      0.669443   0.760912
# 6           6       1.455153       -0.694408      0.662593   0.763300
# 7           7       1.441702       -0.690710      0.656459   0.764380
# 8           8       1.443440       -0.691905      0.651196   0.763796
# 9           9       1.443071       -0.693039      0.638198   0.763042
#
#    gravity.y  gravity.z  rotationRate.x  rotationRate.y  rotationRate.z  \
# 0   0.669768  -0.031672        0.316738        0.778180        1.082764
# ...

# %% [markdown]
# ---

# %% [markdown]
# + Verificação da existêntia de valores nulos

# %%
#Conta os nulos de cada coluna e soma-os 
nan_counts = df_motionSense.apply(lambda col: col.isna().sum())

#Apresenta os resultados para cada coluna
for feature, count in nan_counts.items():
    print(f"{feature} - {count}")
# Out:
# Unnamed: 0 - 0
# attitude.roll - 0
# attitude.pitch - 0
# attitude.yaw - 0
# gravity.x - 0
# gravity.y - 0
# gravity.z - 0
# rotationRate.x - 0
# rotationRate.y - 0
# rotationRate.z - 0
# userAcceleration.x - 0
# userAcceleration.y - 0
# userAcceleration.z - 0
# subject_id - 0
# session_id - 0
# category - 0
# age - 0
# gender - 0
# height - 0
# weight - 0

# %% [markdown]
# + Verificação do tipo de dados em cada coluna

# %%
print(df_motionSense.dtypes)
# Out:
# Unnamed: 0              int64
# attitude.roll         float64
# attitude.pitch        float64
# attitude.yaw          float64
# gravity.x             float64
# gravity.y             float64
# gravity.z             float64
# rotationRate.x        float64
# rotationRate.y        float64
# rotationRate.z        float64
# userAcceleration.x    float64
# userAcceleration.y    float64
# userAcceleration.z    float64
# subject_id              int64
# session_id              int64
# category               object
# age                     int64
# gender                  int64
# height                  int64
# weight                  int64
# dtype: object

# %%
df_motionSense.describe()
# Out:
#           Unnamed: 0  attitude.roll  attitude.pitch   attitude.yaw  \
# count  423372.000000  423372.000000   423372.000000  423372.000000
# mean     1402.021728      -0.036592       -1.148809       0.036178
# std      1074.470810       1.609118        0.373107       1.773952
# min         0.000000      -3.141573       -1.569092      -3.141552
# 25%       552.000000      -1.273642       -1.365143      -1.288355
# 50%      1151.000000       0.153869       -1.236625      -0.038043
# 75%      2037.000000       1.127359       -1.055019       1.506838
# max      5534.000000       3.141566        1.567175       3.141572
#
#            gravity.x      gravity.y      gravity.z  rotationRate.x  \
# count  423372.000000  423372.000000  423372.000000   423372.000000
# mean        0.031095       0.870789      -0.085205        0.011581
# std         0.305190       0.246911       0.281753        1.870887
# min        -0.999822      -0.999993      -0.998837      -17.365788
# ...

# %% [markdown]
# ## **Visualização da Distribuição dos Dados**
#
# We use Seaborn and Matplotlib to create a countplot, visualizing the distribution of numerical codes in the 'code' column of the DataFrame 'df.' This plot provides insight into the frequency of different categories in the dataset.

# %% [markdown]
# + Cálculo da quantidade de ocorrências de cada valor na coluna 'category' do DataFrame df_motionSense utilizando a função `value_counts` do pandas

# %%
category_counts = df_motionSense['category'].value_counts()
category_counts
# Out:
# category
# ups    157285
# jog    134231
# dws    131856
# Name: count, dtype: int64

# %% [markdown]
# + Apresentação de um gráfico de barras que exibe a contagem de valores para a coluna 'category' do DataFrame df_motionSense, utilizando as bibliotecas matplotlib e seaborn

# %%
plt.figure(figsize=(8, 5))

sns.countplot(df_motionSense['category'], color='skyblue')
plt.title('Category Value Counts')
plt.xlabel('Counts')
plt.ylabel('Category')
plt.grid(axis='x', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# + Apresentação de várias visualizações para explorar os metadados dos 24 participantes, que inclui informações sobre idade, gênero, altura e peso. Utilizou-se para tal as bibliotecas matplotlib e seaborn para criar histogramas e gráficos de contagem.

# %%
plt.figure(figsize=(14, 10))

# Idades
plt.subplot(3, 2, 1)
sns.histplot(df_motionSense['age'], kde=True)
plt.title('Distribuição de Idades')
plt.xlabel('Idade')
plt.ylabel('Contagem')

# Gêneros
plt.subplot(3, 2, 2)
sns.countplot(x='gender', data=df_motionSense)
plt.title('Distribuição de Gênero')
plt.xlabel('Gênero')
plt.ylabel('Contagem')

# Alturas
plt.subplot(3, 2, 3)
sns.histplot(df_motionSense['height'], kde=True)
plt.title('Distribuição de Altura')
plt.xlabel('Altura')
plt.ylabel('Contagem')

# Pesos
plt.subplot(3, 2, 4)
sns.histplot(df_motionSense['weight'], kde=True)
plt.title('Distribuição de Peso')
plt.xlabel('Peso')
plt.ylabel('Contagem')

plt.tight_layout()
plt.show()

# %%
#plt.figure(figsize=(20, 10))
#plt.subplot(1, 3, 1)
#sns.boxplot(x='category', y='userAcceleration.x', data=df_motionSense)
#plt.title('Aceleração do Usuário (X) por Categoria')

#plt.subplot(1, 3, 2)
#sns.boxplot(x='category', y='userAcceleration.y', data=df_motionSense)
#plt.title('Aceleração do Usuário (Y) por Categoria')

#plt.subplot(1, 3, 3)
#sns.boxplot(x='category', y='userAcceleration.z', data=df_motionSense)
#plt.title('Aceleração do Usuário (Z) por Categoria')
